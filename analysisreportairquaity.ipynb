# %%
 Complete Analysis & Interpretation (EDA + Statistics)
🔹 1. PM2.5, NO₂, SO₂, AQI Trends for Delhi and Ahmedabad
       Code Used: Time-series plots with trendlines

       Findings:

          >Delhi shows consistently higher pollution levels, especially for PM2.5 and AQI

          >Seasonal spikes (post-monsoon, winter) are very visible

          >Ahmedabad shows less frequent severe spikes than Delhi

🔹 2. AQI Category Distribution (All Cities)
       Visualization: Bar chart / Pie chart of AQI_Bucket

       Insights:

          >Most days fall under “Moderate” and “Poor” categories

          >“Severe” AQI days are concentrated in Delhi, Lucknow, Kanpur

          >Very few “Good” AQI days across Indian cities

🔹 3. Box Plots: Pollutant Levels Across Metro Cities
       Used: Box plots for PM2.5, NO2, SO2, and CO across Delhi, Mumbai, Bengaluru, Chennai

       Observations:

          >Delhi and Kolkata have higher medians and wider spread in PM2.5

          >Mumbai shows more stable pollutant levels

          >Bengaluru has the lowest concentration ranges

🔹 4. Correlation Between Pollutants and AQI
       Used: Correlation heatmap / .corr() + regplots

       Result:

          >PM2.5 and PM10 show the strongest positive correlation with AQI

          >NO₂ and NOx have moderate positive correlation

          >O₃ and Benzene show weak or negative correlation

🔹 5. Top 5 Cities with Most AQI Records
       Code: df['City'].value_counts().head(5)

       Top Cities:

         >Delhi

         >Mumbai

         >Bengaluru

         >Chennai

         >Kolkata

🔹 6. Monthly AQI Trends per City
       Used: Monthly grouped plots by YearMonth

       Insights:

        >Worst Months: October to January (esp. post-Diwali & winter)

        >Best Months: June to August (monsoon effect)

        >Cities show clear seasonal pollution cycles

🔹 7. North vs South India: Pollutant Comparison
       Used: Grouped bar chart (region-wise means)

       Observation:

        >North Indian cities (Delhi, Kanpur, Lucknow) have 2x–3x higher PM2.5 & PM10

        >South India (Chennai, Bengaluru) shows lower NO₂ and SO₂

        >Possible factors: vehicle density, stubble burning, industrial belts

🔹 8. Heatmap of Average AQI per City per Month
       Used: Pivot table + sns.heatmap

       Findings:

         >Delhi, Lucknow, and Kanpur consistently show dark red cells (high AQI)

         >Coastal cities (Mumbai, Chennai) show better air quality, especially during monsoons

🔹 9. Top 3 Pollutants Most Frequent on “Severe” AQI Days
       Method: Count non-null occurrences on AQI_Bucket == "Severe"

       Result:

         > PM2.5

         > NO

         > NO₂

         >These consistently appear on nearly every "Severe" AQI day

🔹 10. CO vs NO₂ Relationship
        Used: Scatter plot with regression line + Pearson correlation

        Result:

         >Weak positive correlation (r ≈ 0.17)

         >Suggests slight association, possibly due to vehicular sources

         >But CO and NO₂ may have distinct emission patterns

🔹 11. Delhi AQI Trend (2015–2020)
        Used: Line plot + 6-month moving average

        Finding:

         >AQI showed improvement trend from late 2017 to 2020

>2020 had best AQI levels, likely due to lockdown effects

Seasonal peaks remain, but general levels trended downward

📌 Conclusion
The analysis confirms that:

Delhi and North Indian cities face critical air pollution especially from PM2.5 and NO₂

AQI seasonality is consistent across cities — worst in winters

Data-driven interventions should target PM2.5 & NO₂ control, especially pre-winter

Long-term data shows marginal improvements in cities like Delhi by 2020
